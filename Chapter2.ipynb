# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('data/Advertising.csv', index_col=0)
df.shape
# Out:
# (200, 4)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
plt.scatter(df['TV'], df['Sales'])

# %%
df = pd.read_csv('data/College.csv', index_col=0)

# %%
df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
# Private        777 non-null object
# Apps           777 non-null int64
# Accept         777 non-null int64
# Enroll         777 non-null int64
# Top10perc      777 non-null int64
# Top25perc      777 non-null int64
# F.Undergrad    777 non-null int64
# P.Undergrad    777 non-null int64
# Outstate       777 non-null int64
# Room.Board     777 non-null int64
# Books          777 non-null int64
# Personal       777 non-null int64
# PhD            777 non-null int64
# Terminal       777 non-null int64
# S.F.Ratio      777 non-null float64
# perc.alumni    777 non-null int64
# Expend         777 non-null int64
# Grad.Rate      777 non-null int64
# dtypes: float64(1), int64(16), object(1)
# memory usage: 115.3+ KB

# %%
numerical = list(df.columns[0:5])
numerical.remove('Private')
numerical
# Out:
# ['Apps', 'Accept', 'Enroll', 'Top10perc']

# %%
# %config InlineBackend.figure_format = 'png'
sns.pairplot(df[numerical]);

# %%
sns.boxplot(y='Outstate', x='Private', data=df)

# %%
df['Elite'] = df['Top10perc'] > 50

# %%
df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
sns.boxplot(y='Outstate', x='Elite', data=df)

# %%
df['Elite'].value_counts()
# Out:
# False    699
# True      78
# Name: Elite, dtype: int64

# %%
features = ['Apps', 'Accept', 'Top10perc', 'Top25perc']

# %%
df[features].hist(figsize=(16,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f44afa37a90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f44aad88f60>]], dtype=object)

# %%
df = pd.read_csv('data/Auto.csv', sep='\s+', index_col='name')

# %%
df.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0      130.0  3504.0
# buick skylark 320          15.0          8         350.0      165.0  3693.0
# plymouth satellite         18.0          8         318.0      150.0  3436.0
# amc rebel sst              16.0          8         304.0      150.0  3433.0
# ford torino                17.0          8         302.0      140.0  3449.0
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
pd.concat([df.iloc[0:10], df.iloc[85:]]).describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  322.000000  322.000000    322.000000   322.000000    322.000000
# mean    24.409317    5.378882    187.680124  2936.807453     15.700621
# std      7.913357    1.657398    100.120925   810.987533      2.706436
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.250000  2216.000000     14.000000
# 50%     23.900000    4.000000    145.500000  2797.500000     15.500000
# 75%     30.650000    6.000000    250.000000  3516.000000     17.275000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  322.000000  322.000000
# mean    77.130435    1.596273
# std      3.131849    0.815572
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
plt.scatter(df['mpg'], df['year'])

# %%
plt.scatter(df['mpg'], df['displacement'])

# %%
numerical = ['mpg', 'displacement', 'weight', 'acceleration']
corr_matrix = df[numerical].corr()

# %%
sns.heatmap(corr_matrix)

# %%
df = pd.read_csv('data/Boston.csv', index_col=0)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 1  396.90   4.98  24.0
# 2  396.90   9.14  21.6
# 3  392.83   4.03  34.7
# 4  394.63   2.94  33.4
# 5  396.90   5.33  36.2

# %%
cols = list(df.columns)
cols.remove('crim')
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10,7))
for idx, feat in enumerate(cols):
    ax = axes[int(idx/4), idx%4]
    ax.scatter(df['crim'], df[feat])
    ax.set_ylabel(feat)
fig.tight_layout();

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
features = ['crim', 'tax', 'ptratio']
df[features].hist(figsize=(16,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f44b09b9b38>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f44b022d0b8>]], dtype=object)

# %%
df.sort_values(by='medv', ascending=True).head(10)
# Out:
#          crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 399  38.35180  0.0  18.10     0  0.693  5.453  100.0  1.4896   24  666
# 406  67.92080  0.0  18.10     0  0.693  5.683  100.0  1.4254   24  666
# 401  25.04610  0.0  18.10     0  0.693  5.987  100.0  1.5888   24  666
# 400   9.91655  0.0  18.10     0  0.693  5.852   77.8  1.5004   24  666
# 415  45.74610  0.0  18.10     0  0.693  4.519  100.0  1.6582   24  666
# 490   0.18337  0.0  27.74     0  0.609  5.414   98.3  1.7554    4  711
# 402  14.23620  0.0  18.10     0  0.693  6.343  100.0  1.5741   24  666
# 386  16.81180  0.0  18.10     0  0.700  5.277   98.1  1.4261   24  666
# 416  18.08460  0.0  18.10     0  0.679  6.434  100.0  1.8347   24  666
# 388  22.59710  0.0  18.10     0  0.700  5.000   89.5  1.5184   24  666
#
#      ptratio   black  lstat  medv
# 399     20.2  396.90  30.59   5.0
# 406     20.2  384.97  22.98   5.0
# 401     20.2  396.90  26.77   5.6
# 400     20.2  338.16  29.97   6.3
# ...

# %%
df['chas'].value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
df['ptratio'].median()
# Out:
# 19.05

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
cond = df['rm']>8
df[cond]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 98   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 164  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 205  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 225  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 226  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 227  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 233  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 234  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 254  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 258  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 263  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 268  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...
